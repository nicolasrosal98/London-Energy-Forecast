# %% [markdown]
# # SM_London - Data Cleaning / Feature Engineering

# %%
# Important Libraries
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import numpy as np
from sklearn.cluster import KMeans
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from prince import FAMD
import plotly.express as pex
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline

# %% [markdown]
# ### Importing Data

# %%
#importing Information_Households.csv
infohouse_df = pd.read_csv('/Users/nicolasrosal/Desktop/Machine Learning Projects/SM_London/Info, Acorns & Holidays/informations_households.csv')

# %%
#Creating a daily_df out of daily_blocks
daily_df = pd.DataFrame()

for num in range(0, 112):
    block = pd.read_csv('/Users/nicolasrosal/Desktop/Machine Learning Projects/SM_London/daily_dataset/daily_dataset/block_' + str(num)+ '.csv')
    block = block[['LCLid', 'day', 'energy_sum']] 
    daily_df = pd.concat([daily_df, block])
    
daily_df.to_csv('daily.csv', header = ['LCLid', 'day', 'energy_sum'])

# %%
#Creating a halfhour_df out of hhblocks
halfhour_df = pd.DataFrame()

for num in range(0, 112):
    block = pd.read_csv('/Users/nicolasrosal/Desktop/Machine Learning Projects/SM_London/hhblock_dataset/hhblock_dataset/block_' + str(num) + '.csv')
    halfhour_df = pd.concat([halfhour_df, block])

# %%
#Importing weather dataframe
weather_df = pd.read_csv('/Users/nicolasrosal/Desktop/Machine Learning Projects/SM_London/Weather Data/weather_daily_darksky.csv')

# %%
#Importing holiday dataframe
holiday_df = pd.read_csv('/Users/nicolasrosal/Desktop/Machine Learning Projects/SM_London/Info, Acorns & Holidays/uk_bank_holidays.csv')

# %% [markdown]
# ### Data Cleaning and Feature Engineering

# %% [markdown]
# ##### 1. infohouse_df

# %% [markdown]
# - Data Cleaning:

# %%
#Printing Head
print('Checking head:\n\n{}'.format(infohouse_df.head()))

# %%
# Checking for missing values
print('Checking for NANs:\n\n{}'.format(infohouse_df.isnull().sum()))

# %%
# Checking for inconsistencies in data
print('Checking statistical data:\n\n{}'.format(infohouse_df.describe()))

# %%
# Checking for data types
print('Checking data types:\n\n{}'.format(infohouse_df.dtypes))

# %% [markdown]
# - Feature Engineering:

# %%
#drop file column
infohouse_df.drop('file', axis = 1, inplace = True)
infohouse_df.head()
# Out:
#        LCLid stdorToU    Acorn Acorn_grouped
# 0  MAC005492      ToU   ACORN-        ACORN-
# 1  MAC001074      ToU   ACORN-        ACORN-
# 2  MAC000002      Std  ACORN-A      Affluent
# 3  MAC003613      Std  ACORN-A      Affluent
# 4  MAC003597      Std  ACORN-A      Affluent

# %% [markdown]
# ##### 2. daily_df

# %% [markdown]
# - Data Cleaning:

# %%
#Printing Head
print('Checking head:\n\n{}'.format(daily_df.head()))

# %%
# Checking for missing values
print('Checking for NANs in daily_df:\n\n{}'.format(daily_df.isnull().sum()))

# %%
# Checking for inconsistencies in data
print('Checking statistical data:\n\n{}'.format(daily_df.describe()))

# %%
# Checking for inconsistencies in data
print('Checking data types:\n\n{}'.format(daily_df.dtypes))

# %% [markdown]
# - Feature Engineering:

# %% [markdown]
# ##### 3. halfhour_df

# %% [markdown]
# - Data Cleaning:

# %%
#Printing Head
print('Checking head:\n\n{}'.format(halfhour_df.head()))

# %%
#Checking for missing values
print('Checking for NANs in daily_df:\n\n{}'.format(halfhour_df.isnull().sum()))

# %%
#Checking for inconsistencies in data
print('Checking statistical data:\n\n{}'.format(halfhour_df.describe()))

# %%
#Checking for inconsistencies in data
print('Checking data types:\n\n{}'.format(halfhour_df.dtypes))

# %%
# Using SimpleImputer to replace Nans
imp_median = SimpleImputer(missing_values=np.nan, strategy='median')
halfhour_df['hh_19'] = imp_median.fit_transform(halfhour_df[['hh_19']])
halfhour_df['hh_25'] = imp_median.fit_transform(halfhour_df[['hh_25']])
halfhour_df['hh_26'] = imp_median.fit_transform(halfhour_df[['hh_26']])
halfhour_df['hh_30'] = imp_median.fit_transform(halfhour_df[['hh_30']])
halfhour_df['hh_36'] = imp_median.fit_transform(halfhour_df[['hh_36']])

# %%
#Re-Checking for missing values
print('Checking for NANs in daily_df:\n\n{}'.format(halfhour_df.isnull().sum()))

# %% [markdown]
# - Feature Engineering:

# %%
##Plot hh averages through the day to find patterns

# Compute daily hh averages
hh_mean = [mean for mean in halfhour_df.drop(['LCLid', 'day'], axis = 1).mean()] 

# Create list with times
time = [str(i*dt.timedelta(minutes=30)) for i in range(24*60//30)]

# Plot means vs times
plt.figure(figsize=(9, 6))

plt.plot(time, hh_mean)
plt.grid()
plt.title('Daily Average per Half Hour', fontweight="bold")
plt.xlabel('Time of Day', fontweight="bold")
plt.xticks(np.arange(0, 50 ,2), rotation = 90, fontsize = 8)
plt.ylabel('Half Hour Means', fontweight="bold")
plt.yticks(np.arange(0.1, 0.35, 0.05))

xcoords = ['4:00:00', '8:30:00', '14:30:00', '19:30:00']
for xc in xcoords:
    plt.axvline(x=xc, color = 'r', linestyle = '--')
    
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We identified four patterns in the half hour average per day graph: <b>1) </b> from <b>4:00:00 to 8:30:00</b> there appears to be an ascending trend, <b>2) </b> from <b>8:30:00 to 14:30:00</b> the average stabilizes, <b>3) </b> from <b>14:30:00 to 19:30:00</b> the ascending trend resumes, and <b>4) </b> from <b>19:30:00 to 4:00:00</b> the trend shifts to a downward trend. Hence, we used this four time intervals to group half hour reading by time of day, namely 'Dawn', 'Morning-Afternoon', 'Evening', and 'Night'.
# </div>

# %%
# Renaming columns of halfhour_df
columns = ['LCLid', 'day']
for hh in time:
    columns.append(hh)
halfhour_df.columns = columns

# %%
# Group half hours into 'Dawn', 'Morning-Afternoon', 'Evening', and 'Night' groups
# and compute average of group
halfhour_df['Avg.Dawn'] = halfhour_df.iloc[:, 11:20].mean(axis=1)
halfhour_df['Avg.Morning_Afternoon'] = halfhour_df.iloc[:, 20:32].mean(axis=1)
halfhour_df['Avg.Evening'] = halfhour_df.iloc[:, 32:42].mean(axis=1)
halfhour_df['Avg.Night'] = halfhour_df.loc[:, list(halfhour_df.columns[2:11]) + 
           list(halfhour_df.columns[42:-1])].mean(axis = 1)

#Update data frame with created columns
halfhour_df = halfhour_df[['LCLid', 'day', 'Avg.Dawn', 'Avg.Morning_Afternoon', 
                       'Avg.Evening', 'Avg.Night']]

#Create holiday column (binary) in halfhour_df
halfhour_df['holiday'] = [1 if date in list(holiday_df['Bank holidays']) else 0 for date in halfhour_df['day']]

# %%
#Concatenating halfhour_df and infohouse_df
halfhour_df = halfhour_df.merge(infohouse_df, on=('LCLid'))

#Replace Acorn- with most frequent
halfhour_df['Acorn'].value_counts() #Identified Acorn-E as most frequent
halfhour_df['Acorn'].replace('Acorn-', 'Acorn-E')

# %%
#Verifying changes
print(halfhour_df.head())
print(halfhour_df.columns)
# Out:
#        LCLid         day  Avg.Dawn  Avg.Morning_Afternoon  Avg.Evening  \
# 0  MAC000002  2012-10-13  0.133556               0.266667       0.2927
# 1  MAC000002  2012-10-14  0.100556               0.243500       0.4453
# 2  MAC000002  2012-10-15  0.213111               0.149417       0.3413
# 3  MAC000002  2012-10-16  0.103667               0.253750       0.2913
# 4  MAC000002  2012-10-17  0.106111               0.401917       0.1687
#
#    Avg.Night  holiday stdorToU_x  Acorn_x Acorn_grouped_x  ...  \
# 0   0.218854        0        Std  ACORN-A        Affluent  ...
# 1   0.278266        0        Std  ACORN-A        Affluent  ...
# 2   0.183975        0        Std  ACORN-A        Affluent  ...
# 3   0.170285        0        Std  ACORN-A        Affluent  ...
# 4   0.206738        0        Std  ACORN-A        Affluent  ...
#
#   Acorn_grouped_y stdorToU_x  Acorn_x Acorn_grouped_x stdorToU_y  Acorn_y  \
# 0        Affluent        Std  ACORN-A        Affluent        Std  ACORN-A
# 1        Affluent        Std  ACORN-A        Affluent        Std  ACORN-A
# 2        Affluent        Std  ACORN-A        Affluent        Std  ACORN-A
# 3        Affluent        Std  ACORN-A        Affluent        Std  ACORN-A
# 4        Affluent        Std  ACORN-A        Affluent        Std  ACORN-A
#
#   Acorn_grouped_y stdorToU    Acorn Acorn_grouped
# 0        Affluent      Std  ACORN-A      Affluent
# 1        Affluent      Std  ACORN-A      Affluent
# 2        Affluent      Std  ACORN-A      Affluent
# 3        Affluent      Std  ACORN-A      Affluent
# 4        Affluent      Std  ACORN-A      Affluent
#
# [5 rows x 22 columns]
# Index(['LCLid', 'day', 'Avg.Dawn', 'Avg.Morning_Afternoon', 'Avg.Evening',
#        'Avg.Night', 'holiday', 'stdorToU_x', 'Acorn_x', 'Acorn_grouped_x',
#        'stdorToU_y', 'Acorn_y', 'Acorn_grouped_y', 'stdorToU_x', 'Acorn_x',
#        'Acorn_grouped_x', 'stdorToU_y', 'Acorn_y', 'Acorn_grouped_y',
#        'stdorToU', 'Acorn', 'Acorn_grouped'],
#       dtype='object')

# %%
halfhour_df['Acorn'].value_counts()
# Out:
# ACORN-E    1011407
# ACORN-Q     526266
# ACORN-F     441804
# ACORN-H     268989
# ACORN-L     201723
# ACORN-D     186880
# ACORN-G     122381
# ACORN-K     105129
# ACORN-A      91872
# ACORN-N      90803
# ACORN-C      87783
# ACORN-P      71297
# ACORN-M      65461
# ACORN-J      64043
# ACORN-O      60135
# ACORN-U      29167
# ACORN-I      29120
# ACORN-B      14321
# ACORN-         771
# Name: Acorn, dtype: int64

# %% [markdown]
# ##### 4. weather_df

# %% [markdown]
# - Data Cleaning:

# %%
#Printing Head
print('Checking head:\n\n{}'.format(weather_df.head()))

# %%
# Checking for missing values
print('Checking for NANs in daily_df:\n\n{}'.format(weather_df.isnull().sum()))

# %%
# Checking for inconsistencies in data
print('Checking statistical data:\n\n{}'.format(weather_df.describe()))

# %%
# Checking for inconsistencies in data
print('Checking data types:\n\n{}'.format(weather_df.dtypes))

# %%
# Using SimpleImputer to replace Nans
imp_median = SimpleImputer(missing_values=np.nan, strategy='median')
imp_freq = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
weather_df['uvIndex'] = imp_median.fit_transform(weather_df[['uvIndex']])
weather_df['cloudCover'] = imp_median.fit_transform(weather_df[['cloudCover']])
weather_df['uvIndexTime'] = imp_freq.fit_transform(weather_df[['uvIndexTime']])

# %%
#Re-Checking for inconsistencies in data
print('Checking data types:\n\n{}'.format(weather_df.dtypes))

# %% [markdown]
# - Feature Engineering:

# %%
#Creating day column and sorting by day
weather_df.insert(0, 'day', pd.to_datetime(weather_df['time']).dt.date)
weather_df['day'] = pd.to_datetime(weather_df['day'])
weather_df.sort_values(by='day')
# Out:
#            day  temperatureMax   temperatureMaxTime  windBearing  \
# 13  2011-11-01           15.57  2011-11-01 15:00:00          208
# 60  2011-11-02           15.19  2011-11-02 23:00:00          134
# 34  2011-11-03           17.41  2011-11-03 14:00:00          154
# 31  2011-11-04           15.54  2011-11-04 11:00:00          179
# 46  2011-11-05           13.94  2011-11-05 15:00:00          346
# ..         ...             ...                  ...          ...
# 874 2014-03-27           10.04  2014-03-27 13:00:00           75
# 876 2014-03-28           12.43  2014-03-28 14:00:00           87
# 867 2014-03-29           18.47  2014-03-29 14:00:00          105
# 844 2014-03-30           16.37  2014-03-31 13:00:00          138
# 830 2014-03-30           19.82  2014-03-30 12:00:00          114
#
#                     icon  dewPoint   temperatureMinTime  cloudCover  \
# 13     partly-cloudy-day     10.13  2011-11-01 22:00:00        0.36
# 60   partly-cloudy-night     10.23  2011-11-02 03:00:00        0.39
# 34     partly-cloudy-day     13.39  2011-11-03 21:00:00        0.52
# 31                   fog     12.03  2011-11-04 23:00:00        0.50
# 46                   fog     10.96  2011-11-05 02:00:00        0.65
# ..                   ...       ...                  ...         ...
# 874                  fog      2.08  2014-03-27 05:00:00        0.44
# 876                  fog      3.67  2014-03-28 03:00:00        0.19
# 867            clear-day      5.37  2014-03-29 01:00:00        0.08
# 844    partly-cloudy-day      7.61  2014-03-31 06:00:00        0.32
# 830    partly-cloudy-day      5.81  2014-03-30 05:00:00        0.31
#
#      windSpeed  pressure  ... temperatureHigh          sunriseTime  \
# 13        2.45   1009.46  ...           15.57  2011-11-01 06:54:29
# 60        4.39   1004.79  ...           15.06  2011-11-02 06:56:16
# 34        3.99    993.40  ...           17.41  2011-11-03 06:58:03
# 31        2.62    995.54  ...           15.54  2011-11-04 06:59:49
# 46        2.70   1007.39  ...           13.94  2011-11-05 07:01:36
# ..         ...       ...  ...             ...                  ...
# 874       2.36   1012.88  ...           10.04  2014-03-27 05:48:40
# 876       3.31   1014.82  ...           12.43  2014-03-28 05:46:23
# 867       4.19   1014.25  ...           18.47  2014-03-29 05:44:05
# 844       1.92   1012.74  ...           16.37  2014-03-31 05:39:30
# 830       2.18   1013.04  ...           19.82  2014-03-30 05:41:48
#
#      temperatureHighTime          uvIndexTime  \
# 13   2011-11-01 15:00:00  2011-11-01 10:00:00
# 60   2011-11-02 13:00:00  2011-11-02 09:00:00
# 34   2011-11-03 14:00:00  2011-11-03 10:00:00
# 31   2011-11-04 11:00:00  2011-11-04 10:00:00
# 46   2011-11-05 15:00:00  2011-11-05 10:00:00
# ..                   ...                  ...
# 874  2014-03-27 13:00:00  2014-03-27 13:00:00
# 876  2014-03-28 14:00:00  2014-03-28 11:00:00
# 867  2014-03-29 14:00:00  2014-03-29 12:00:00
# 844  2014-03-31 13:00:00  2014-03-31 12:00:00
# 830  2014-03-30 12:00:00  2014-03-30 11:00:00
#
#                                                summary   temperatureLowTime  \
# 13                        Partly cloudy until evening.  2011-11-02 03:00:00
# 60                   Partly cloudy throughout the day.  2011-11-02 19:00:00
# 34                   Partly cloudy throughout the day.  2011-11-04 07:00:00
# 31                                    Foggy overnight.  2011-11-05 02:00:00
# 46                               Foggy in the morning.  2011-11-06 05:00:00
# ..                                                 ...                  ...
# 874                                   Foggy overnight.  2014-03-28 03:00:00
# 876                              Foggy in the morning.  2014-03-29 01:00:00
# 867                          Clear throughout the day.  2014-03-30 05:00:00
# 844                       Mostly cloudy until evening.  2014-04-01 06:00:00
# 830  Mostly cloudy starting in the afternoon, conti...  2014-03-31 06:00:00
#
#      apparentTemperatureMin  apparentTemperatureMaxTime  \
# 13                     9.01         2011-11-01 15:00:00
# 60                     7.33         2011-11-02 23:00:00
# 34                    12.79         2011-11-03 14:00:00
# 31                    11.53         2011-11-04 11:00:00
# 46                    10.17         2011-11-05 15:00:00
# ..                      ...                         ...
# 874                    0.62         2014-03-27 13:00:00
# 876                    1.69         2014-03-28 14:00:00
# 867                    5.41         2014-03-29 14:00:00
# 844                   10.98         2014-03-31 13:00:00
# 830                    8.14         2014-03-30 12:00:00
#
#      apparentTemperatureLowTime moonPhase
# 13          2011-11-02 03:00:00      0.21
# 60          2011-11-02 19:00:00      0.24
# 34          2011-11-04 07:00:00      0.27
# 31          2011-11-05 02:00:00      0.31
# 46          2011-11-06 06:00:00      0.34
# ..                          ...       ...
# 874         2014-03-28 03:00:00      0.88
# 876         2014-03-29 02:00:00      0.92
# 867         2014-03-30 04:00:00      0.96
# 844         2014-04-01 06:00:00      0.03
# 830         2014-03-31 06:00:00      0.99
#
# [882 rows x 33 columns]

# %%
#Drop 'apparent' and 'time' columns
weather_df.drop(weather_df.loc[:,weather_df.columns.str.contains("apparent")], axis=1, inplace = True)
weather_df.drop(weather_df.loc[:,weather_df.columns.str.contains("time")], axis=1, inplace = True)

# %%
# Drop irrelevant time columns and keeping sunset and sunrise times
weather_df['sunset'] = pd.to_datetime(weather_df['sunsetTime']).dt.round('H').dt.time
weather_df['sunrise'] = pd.to_datetime(weather_df['sunriseTime']).dt.round('H').dt.time
weather_df.drop(weather_df.loc[:,weather_df.columns.str.contains("Time")], axis=1, inplace = True)

# %%
# Drop 'summary' columns
weather_df.drop('summary', axis = 1, inplace = True)

# %%
# One-Hot Encode Sunrise, Sunset, icon and precipType (for EDA)
# weather_df = pd.get_dummies(weather_df, columns=['sunset', 'sunrise'], prefix=['ohe_sunset', 'ohe_sunrise'])
# weather_df = pd.get_dummies(weather_df, columns=['icon', 'precipType'], prefix=['oheicon', 'oheprecipType'], drop_first = True)

# %% [markdown]
# - Clustering for Feature Engineering:

# %% [markdown]
#      Standarization

# %%
#Initializing Scaler
scaler = StandardScaler()

# %%
#Scale non-binary features
numerical_features = ['temperatureMax', 'windBearing', 'dewPoint',
       'cloudCover', 'windSpeed', 'pressure', 'visibility',
       'humidity', 'uvIndex', 'temperatureLow', 'temperatureMin',
       'temperatureHigh', 'moonPhase']
weather_df[numerical_features] = scaler.fit_transform(weather_df[numerical_features])

# %%
# Verifying change
weather_df.head()
# Out:
#          day  temperatureMax  windBearing                 icon  dewPoint  \
# 0 2011-11-11       -0.275133    -0.814233                  fog  0.594425
# 1 2011-12-11       -0.820508     0.025726    partly-cloudy-day -0.422530
# 2 2011-12-27       -0.538920     0.328111    partly-cloudy-day -0.219553
# 3 2011-12-02       -0.904661     0.406507                 wind -0.588226
# 4 2011-12-24       -0.880386     0.630496  partly-cloudy-night -0.774633
#
#    cloudCover  windSpeed  pressure precipType  visibility  humidity   uvIndex  \
# 0    1.616207   0.176131  0.176426       rain   -3.191913  1.764319 -0.842137
# 1    0.426312   0.211570 -0.579893       rain    0.374428  1.029751 -0.842137
# 2    1.926614  -0.024691  1.683642       rain    0.901873 -0.439384 -1.388288
# 3   -0.815318  -0.343643 -0.181403       rain    0.293283  0.924813 -0.842137
# 4   -0.556645   0.518708  1.268886       rain    0.808556  0.190245 -0.842137
#
#    temperatureLow  temperatureMin  temperatureHigh  moonPhase    sunset  \
# 0        0.649138        0.293863        -0.427129   0.066480  16:00:00
# 1       -0.948975       -1.009841        -0.791541   0.101340  16:00:00
# 2        0.065765        0.126039        -0.513437  -1.397655  16:00:00
# 3       -0.283437       -0.993467        -0.988132  -0.874750  16:00:00
# 4       -0.053375       -0.868623        -0.897029   1.704916  16:00:00
#
#     sunrise
# 0  07:00:00
# 1  08:00:00
# 2  08:00:00
# 3  08:00:00
# 4  08:00:00

# %% [markdown]
#      FAMD

# %%
## Instantiate and FAMD object
famd = FAMD(n_components = 17, engine='auto', check_input=True, random_state=123)
famd = famd.fit(weather_df.iloc[:, 1:])

# %%
# Exploring inertia
inertia_cumsum = np.cumsum(famd.explained_inertia_)

# %%
# Plot inertia to find optimal n_components 
plt.figure(figsize = (9, 6))
plt.plot(range(0, 17), inertia_cumsum, marker = 'x', linestyle = '--')
plt.title('Explained Variance by Number of Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     We decided to keep the number of components that represented 90%+ of the data. Hence, we chose <b>6</b> as the optimal number of components for our FAMD analysis.
# </div>

# %%
#Instantiate FAMD with optimal number of components (explain 90%+ of the data)
famd = FAMD(n_components=6, engine='auto', check_input=True, random_state=123)
famd = famd.fit_transform(weather_df.iloc[:, 1:])
famd_scores = np.array(famd)

# %% [markdown]
#      Clustering

# %%
# Testing for optimal K
distortions = []

for k in range(1,10):
    kmc = KMeans(n_clusters=k, max_iter = 1000, n_init = 20)
    kmc.fit(famd_scores)
    distortions.append(kmc.inertia_)
    
plt.figure(figsize=(9, 6))
plt.plot(range(1,10), distortions, marker = 'o', linestyle = '--')
plt.xlabel('K')
plt.ylabel('Distortion')
plt.title('The Elbow chart showing the optimal k')
plt.axvline(x=4, color = 'g', linestyle = '--')
plt.axvline(x=5, color = 'r', linestyle = '--')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     K = 5 was identified as the optimal k for the KMeans algorithm. Nevertheless, knowing that there are 4 seasons, we decided to shift to optimal <b>K = 4</b>
# </div>

# %%
# Testing KMeans model with optimal K
kmc = KMeans(n_clusters=4, max_iter = 1000, n_init = 20, random_state = 123)

#Creating clusters
clusters = kmc.fit_predict(famd_scores)

# %%
# Concatenate weather_df with fmad_scores and clusters
clusters_df = pd.concat([weather_df.reset_index(drop = True), pd.DataFrame(famd_scores)], axis = 1)
clusters_df.columns.values[-6: ] = [f'Component_{i}' for i in range(1,7)]
clusters_df['Cluster'] = kmc.labels_

# %%
#Identifying seasons in clusters
cluster0 = clusters_df[clusters_df['Cluster'] == 0]['day'].dt.month.value_counts()
print('Value counts per month for cluster0:\n\n{}\n\n'.format(cluster0))
cluster1 = clusters_df[clusters_df['Cluster'] == 1]['day'].dt.month.value_counts()
print('Value counts per month for cluster1:\n\n{}\n\n'.format(cluster1))
cluster2 = clusters_df[clusters_df['Cluster'] == 2]['day'].dt.month.value_counts()
print('Value counts per month for cluster2:\n\n{}\n\n'.format(cluster2))
cluster3 = clusters_df[clusters_df['Cluster'] == 3]['day'].dt.month.value_counts()
print('Value counts per month for cluster3:\n\n{}\n\n'.format(cluster3))
# Out:
# Value counts per month for cluster0:
#
# 7    62
# 6    60
# 5    56
# 8     4
# Name: day, dtype: int64
#
#
# Value counts per month for cluster1:
#
# 3     87
# 2     64
# 10    60
# 9     42
# 11    10
# Name: day, dtype: int64
#
#
# Value counts per month for cluster2:
#
# 12    93
# 1     93
# 11    80
# 2     21
# Name: day, dtype: int64
#
#
# Value counts per month for cluster3:
#
# 4    60
# 8    58
# 9    18
# 3     8
# 5     6
# Name: day, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
#         It is clear that <b>Cluster0</b> and <b>Cluster2</b> can be represented as Summer and Winter, correspondingly. The remianing clusters required an additional interpretation: <b>Cluster1</b> will represent the time of the year in which Autumn and Spring are starting, while <b>Cluster3</b> when they are ending.
# </div>

# %%
#Add Labels to Clusters
clusters_df['Season'] = clusters_df['Cluster'].map({0:'Summer', 1:'StartAut/Spr', 2:'Winter', 3:'EndAut/Spr'})

# %%
# Plotting Clusters
my_plot = pex.scatter_3d(clusters_df, x = 'Component_1', y = 'Component_2', z = 'Component_3', 
                         color='Season', title="Season Clusters")
my_plot.show()
# Out:
# <div>
#
#
#             <div id="e7af5501-81f0-439f-9f1c-5eec15094477" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e7af5501-81f0-439f-9f1c-5eec15094477")) {
#                     Plotly.newPlot(
#                         'e7af5501-81f0-439f-9f1c-5eec15094477',
#                         [{"hovertemplate": "Season=Winter<br>Component_1=%{x}<br>Component_2=%{y}<br>Component_3=%{z}<extra></extra>", "legendgroup": "Winter", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Winter", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [43.24449933648214, 65.28941178951064, 65.29003961322799, 46.31276350942673, 43.99033991055773, 46.312823855941204, 43.24501487487173, 43.244188719499725, 46.31283309883137, 43.24430311376516, 43.24462395427101, 65.28978216209404, 65.28900435427296, 65.29020977765828, 43.99017865440454, 65.28957078875439, 65.28953808005335, 43.9904938555415, 43.24546514794176, 46.312891282274755, 43.99077583137539, 65.28956478871224, 46.313057044781765, 43.244395278513736, 46.31300220796472, 63.26431812613028, 65.29007369905632, 65.28987508525522, 65.29010876214392, 65.2895789902043, 43.245165856733635, 63.264535060228106, 43.24482481350094, 45.270585624902886, 63.26483433620008, 65.28963571305579, 65.2891487148799, 65.28989446921668, 65.29015308735055, 65.28936919705589, 43.24457460926607, 65.28973938559874, 46.31343648861625, 43.24515077214744, 43.245125369664045, 65.28946235550043, 46.31315095514689, 43.24502897903458, 45.270385190984456, 65.28957191869384, 65.29002409008154, 65.28916919559886, 65.28979333673834, 46.31324665430922, 46.31336700901556, 43.244304786628526, 65.28988608866231, 46.31312369001234, 43.990375801062115, 63.264395590992955, 42.69784391393577, 43.99056754434688, 41.96444752633068, 42.69826773550592, 42.69793215357872, 43.989946395516725, 65.28974029418443, 41.96532515865887, 34.803084181912666, 65.29013393406515, 65.28975183643215, 46.3131064557745, 17.354633724917136, 14.783781387965085, 65.2901683617644, 65.28971443341153, 65.28944971921712, 63.264145163666306, 65.289842644468, 43.24525302156821, 41.96472615078204, 65.28974877074043, 43.98975556546816, 63.26382413523761, 46.31292220974155, 65.28978359637031, 43.989741372883174, 65.28966907401657, 62.71721772266744, 65.28917195254785, 62.71851304213418, 43.2443201145549, 46.31287961694009, 65.29014520819779, 65.2896011785909, 45.27035249524732, 63.26472515340903, 17.355024142732727, 63.26420622830921, 65.28983596768676, 46.31311092183611, 43.99018102847571, 46.3129038829364, 46.311946471522, 65.29006494337928, 65.28964576621657, 43.99016098133911, 65.29009962753757, 63.264303689687885, 41.418990557218144, 62.71839390995652, 63.26483937911703, 43.98947379420849, 43.989578253208336, 46.31276277453073, 43.99044157329301, 65.28944175292544, 65.29016140663153, 65.28970882646975, 42.69793426793717, 46.3129257655562, 43.9901598611008, 37.37367160788412, 65.28948171763842, 34.80354881994137, 65.28943357096844, 62.71826742086628, 65.28964071808043, 46.31305056408397, 46.31299445578772, 43.989371936450254, 62.71834981227657, 65.2889868991394, 62.717935352021975, 65.29003502115815, 65.28948772722867, 45.26990590007762, 41.41944545738887, 63.2639351844544, 65.28906517519432, 65.28953468921671, 65.28977132657599, 34.80321780003254, 65.28882529922265, 43.24424463298992, 41.96490336934908, 46.311989212068816, 62.717472093874726, 65.28988206686778, 63.264383140677694, 65.28958391891402, 41.96454426323225, 43.98961940896288, 65.2886822711884, 65.28965363520896, 46.31314555325936, 45.26971913148525, 63.2639530111509, 65.28991073160981, 65.29002667856723, 65.28960093194692, 63.26414478375354, 65.28962828638711, 43.291850468603286, 65.2896988510064, 17.354369692674233, 63.264339514412924, 43.741652048116634, 62.718353241755004, 63.26407803515817, 63.26455990678422, 43.24455415610101, 46.31276785172761, 46.31263874546471, 65.28936426434845, 65.28887120510241, 63.26435779448753, 65.28992240492627, 46.31278831772603, 65.28881425066811, 63.264255515350115, 65.28961343533723, 62.71709214944443, 65.28840889383079, 65.29008632323081, 45.27014766497913, 63.264417698463475, 62.718388368600856, 43.741862655275995, 62.718551486587174, 62.717350309297935, 46.31224369521072, 43.990389934303174 ...

# %%
#Creating a Season column in weather_df
weather_df['Season'] = clusters_df['Season']

# %%
#Weather_df to csv
weather_df.to_csv('weather_df.csv')
